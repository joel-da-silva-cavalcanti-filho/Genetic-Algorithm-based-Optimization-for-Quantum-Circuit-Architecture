# %% [markdown]
# ### Extracting the patches, embedding data and running through a toy ansatz

# %%
import numpy as np
import torch
import torch.nn as nn 
import torch.utils.data as data
import torch.optim as optim
import torchvision.transforms as transforms
from medmnist import INFO, Evaluator, BreastMNIST
import medmnist
import math

# %%
data_flag = 'breastmnist'
download = True

info = INFO[data_flag]
DataClass = getattr(medmnist, info['python_class'])

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5])
])

train_dataset = DataClass(split='train', transform=data_transform, download=download, size=224, mmap_mode='r')
# Out:
# 100%|██████████| 30.9M/30.9M [00:08<00:00, 3.52MB/s]

# %%
train_dataset.montage(length=3)
# Out:
# <PIL.Image.Image image mode=L size=672x672>

# %%
image = train_dataset.imgs[0]
no_patches = 1
patch_size = 2
enconding = []
for row in range(patch_size):
    for column in range(patch_size):
        enconding.append(math.pi * image[row][column]/255)

# %%
torch.tensor(enconding)
# Out:
# tensor([1.9835, 1.9835, 1.9096, 1.8603], dtype=torch.float64)

# %%
import src.genetic_algo.quantum_circuit_tensor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import src.genetic_algo.quantum_circuit_tensor
#
# ModuleNotFoundError: No module named 'src'

# %%
def run_gate(state_vector, gate):
    ra
